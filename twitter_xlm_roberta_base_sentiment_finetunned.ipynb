# %%
import pandas as pd
import numpy as np
import transformers
import re
from matplotlib import pyplot as plt

# %%
stat = pd.read_csv("C:/Users/aredko/Downloads/CoronavirusPL - General.csv")
twits = pd.read_csv("C:/Users/aredko/Downloads/tweets_till_31_07_text/tweets_till_31_07_text.csv", encoding='latin1')

# %%
twits['clean_text'] = twits['text'].apply(lambda x: re.sub(r'#\w+', '', x))

# %%
stat
# Out:
#       Timestamp  Confirmed  Deaths  Recovered  In_the_hospital  In_quarantine  \
# 0    03-03-2020          0       0          0               68            316
# 1    04-03-2020          1       0          0               65            349
# 2    05-03-2020          1       0          0               92            490
# 3    06-03-2020          5       0          0              128           1299
# 4    07-03-2020          6       0          0              146           1548
# ..          ...        ...     ...        ...              ...            ...
# 102  13-06-2020      29017    1237       9416             1748          93094
# 103  14-06-2020      29392    1247       9555             1736          94518
# 104  15-06-2020      29788    1256       9668             1806          95641
# 105  16-06-2020      30195    1272       9936             1693          96255
# 106  17-06-2020      30701    1286      10284             1849          93722
#
#      Under_medical_supervision  Number_of_tests_carried_out
# 0                         4459                          559
# 1                         4540                          584
# 2                         5647                          676
# 3                         6184                          855
# 4                         6409                          856
# ..                         ...                          ...
# 102                      18666                      1169088
# 103                      17966                      1188742
# 104                      17261                      1202024
# 105                      17195                      1221133
# 106                      17354                      1247099
#
# [107 rows x 8 columns]

# %%
twits = twits[(twits.time > '2020-03-03 00:00:01') & (twits.time < '2020-06-17 00:00:01')]

# %%
twits
# Out:
#          Unnamed: 0                                               text  \
# 26099         26100  Andrzej Sosnierz: Nie wiem, na jakiej podstawi...
# 26100         26101  Afera Argenty to rzadowe zakupy (po paserskich...
# 26101         26102  prezencik dla kuchcinskiego i innych pedofili ...
# 26102         26103  prezencik dla kuchcinskiego i innych pedofili ...
# 26103         26104  Swiatowej slawy prawnik  David Matas  tlumac...
# ...             ...                                                ...
# 1015194     1015195  Wiceminister rolnictwa nareszcie przyznal, ze ...
# 1015195     1015196  Andrzej Sosnierz: Nie wiem, na jakiej podstawi...
# 1015196     1015197  Afera Argenty to rzadowe zakupy (po paserskich...
# 1015197     1015198  #wtylewizji #pandemia #koronawirus #obostrzeni...
# 1015198     1015199  Wiceminister rolnictwa nareszcie przyznal, ze ...
#
#                         time  \
# 26099    2020-05-29 00:08:42
# 26100    2020-05-29 00:03:07
# 26101    2020-05-29 00:02:35
# 26102    2020-05-28 23:58:17
# 26103    2020-05-28 23:55:47
# ...                      ...
# 1015194  2020-05-29 00:37:29
# 1015195  2020-05-29 00:33:01
# 1015196  2020-05-29 00:29:55
# 1015197  2020-05-29 00:28:21
# 1015198  2020-05-29 00:27:46
#
#                                                 clean_text
# 26099    Andrzej Sosnierz: Nie wiem, na jakiej podstawi...
# 26100    Afera Argenty to rzadowe zakupy (po paserskich...
# 26101    prezencik dla kuchcinskiego i innych pedofili ...
# 26102    prezencik dla kuchcinskiego i innych pedofili ...
# 26103    Swiatowej slawy prawnik  David Matas  tlumac...
# ...                                                    ...
# 1015194  Wiceminister rolnictwa nareszcie przyznal, ze ...
# 1015195  Andrzej Sosnierz: Nie wiem, na jakiej podstawi...
# 1015196  Afera Argenty to rzadowe zakupy (po paserskich...
# 1015197               jedyny, ktory nie czeka na otwarc...
# 1015198  Wiceminister rolnictwa nareszcie przyznal, ze ...
#
# [899826 rows x 4 columns]

# %%
clean_tweet
# Out:
# 'Rekordowa frekwencja? Przeciez mamy WIELKA EPIDEMIE! Ludzie otworzcie oczy! Bo sami sobie przeczycie!        '

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

#tokenizer = AutoTokenizer.from_pretrained("bardsai/twitter-sentiment-pl-base")
#model = AutoModelForSequenceClassification.from_pretrained("bardsai/twitter-sentiment-pl-base")
#citizenlab/twitter-xlm-roberta-base-sentiment-finetunned

tokenizer = AutoTokenizer.from_pretrained("citizenlab/twitter-xlm-roberta-base-sentiment-finetunned")
model = AutoModelForSequenceClassification.from_pretrained("citizenlab/twitter-xlm-roberta-base-sentiment-finetunned")

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader


class MyDataset(Dataset):
    def __init__(self, tokenizer, input_texts, max_length=128):
        self.tokenizer = tokenizer
        self.input_texts = input_texts
        self.max_length = max_length

    def __len__(self):
        return len(self.input_texts)

    def __getitem__(self, idx):
        input_text = self.input_texts[idx]

        # Кодирование для seq2seq задачи
        encoding = self.tokenizer(
            input_text,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
        }

# %%
eval_texts = twits.clean_text.values

# %%
dataset = MyDataset(tokenizer, eval_texts)
loader = DataLoader(dataset, batch_size=128, shuffle=False)

# %%
device = 'cuda'
res = []
model = model.eval().to(device)
with torch.no_grad():
    for batch in loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)

        outputs = model(input_ids=input_ids, attention_mask=attention_mask).logits.detach().to('cpu')
        res.append(outputs)

# %%
preds = np.concatenate(res).argmax(axis = -1)

# %%
negatives = preds==2
posetive = preds==0
neutral = preds== 1

# %%
twits['neg'] = negatives

# %%
twits['preds'] = preds

# %%
twits['time'] = pd.to_datetime(twits['time'])

# Группировка по дням и вычисление среднего значения столбца 'predict'
df_grouped = pd.DataFrame(twits.groupby(twits['time'].dt.date)['preds'].mean()/2)
df_grouped2 = pd.DataFrame(twits.groupby(twits['time'].dt.date)['neg'].sum())
df_grouped3 = pd.DataFrame(twits.groupby(twits['time'].dt.date)['neg'].mean())

df_grouped = df_grouped.reset_index()
df_grouped['time'] = pd.to_datetime(df_grouped['time'])

df_grouped3 = df_grouped3.reset_index()
df_grouped3['time'] = pd.to_datetime(df_grouped3['time'])

df_grouped2 = df_grouped2.reset_index()
df_grouped2['time'] = pd.to_datetime(df_grouped2['time'])

# %%
df_grouped3.columns = ['time','neg_perc']

# %%
stat['time'] = pd.to_datetime(stat['Timestamp'], format='%d-%m-%Y')

# %%
stat = stat[:-1]

# %%
merged_df = stat.merge(df_grouped, left_on = 'time', right_on = 'time')
merged_df = merged_df.merge(df_grouped2, left_on = 'time', right_on = 'time')
merged_df = merged_df.merge(df_grouped3, left_on = 'time', right_on = 'time')

# %%
merged_df['preds'] = 1-merged_df['preds']

# %%
merged_df.to_csv('twits_twitter_sentiment_model.csv')

# %%
merged_df['Deaths_value'] = merged_df['Deaths'].diff()

# Заполнение пропущенного значения первого дня
merged_df.loc[0, 'Deaths_value'] = merged_df.loc[0, 'Deaths']

# %%
merged_df
# Out:
#       Timestamp  Confirmed  Deaths  Recovered  In_the_hospital  In_quarantine  \
# 0    03-03-2020          0       0          0               68            316
# 1    04-03-2020          1       0          0               65            349
# 2    05-03-2020          1       0          0               92            490
# 3    06-03-2020          5       0          0              128           1299
# 4    07-03-2020          6       0          0              146           1548
# ..          ...        ...     ...        ...              ...            ...
# 101  12-06-2020      28577    1222       9221             1711          92654
# 102  13-06-2020      29017    1237       9416             1748          93094
# 103  14-06-2020      29392    1247       9555             1736          94518
# 104  15-06-2020      29788    1256       9668             1806          95641
# 105  16-06-2020      30195    1272       9936             1693          96255
#
#      Under_medical_supervision  Number_of_tests_carried_out       time  \
# 0                         4459                          559 2020-03-03
# 1                         4540                          584 2020-03-04
# 2                         5647                          676 2020-03-05
# 3                         6184                          855 2020-03-06
# 4                         6409                          856 2020-03-07
# ..                         ...                          ...        ...
# 101                      18904                      1150983 2020-06-12
# 102                      18666                      1169088 2020-06-13
# 103                      17966                      1188742 2020-06-14
# 104                      17261                      1202024 2020-06-15
# 105                      17195                      1221133 2020-06-16
#
#         preds  neg  neg_perc  Deaths_value
# 0    0.505886   93  0.017105           0.0
# 1    0.517626  146  0.014789           0.0
# 2    0.517085   55  0.009788           0.0
# 3    0.515115   48  0.007801           0.0
# 4    0.526665   49  0.010495           0.0
# ..        ...  ...       ...           ...
# 101  0.495757   21  0.014851           7.0
# 102  0.496664   18  0.015013          15.0
# 103  0.503226    7  0.011290          10.0
# 104  0.503296    2  0.001318           9.0
# 105  0.506859    1  0.000686          16.0
#
# [106 rows x 13 columns]

# %%
In_quarantine = merged_df.In_quarantine.values
In_the_hospital = merged_df.In_the_hospital.values
Confirmed = merged_df.Confirmed.values
Deaths = merged_df.Deaths.values
Number_of_tests_carried_out = merged_df.Number_of_tests_carried_out.values
#Deaths_value = merged_df.Deaths_value.values
Recovered = merged_df.Recovered.values
Under_medical_supervision = merged_df.Under_medical_supervision.values
time =  merged_df.time.values
sentiment_mean = merged_df.preds.values
sentiment_neg = merged_df.neg.values
neg_perc = merged_df.neg_perc.values

# %%
fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, sentiment_neg)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
#plt.yscale('log')
plt.ylabel('Neg count')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, neg_perc)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
#plt.yscale('log')
plt.ylabel('Neg percent')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, Confirmed)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('Confirmed')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, In_the_hospital)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('In_the_hospital')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, Number_of_tests_carried_out)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('Number_of_tests_carried_out')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, Deaths)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('Deaths')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, In_quarantine)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('In_quarantine')
# Out:
# Text(0, 0.5, 'In_quarantine')

# %%
import pandas as pd
from scipy.stats import pearsonr

# %%
merged_df.columns[1:8]
# Out:
# Index(['Confirmed', 'Deaths', 'Recovered', 'In_the_hospital', 'In_quarantine',
#        'Under_medical_supervision', 'Number_of_tests_carried_out'],
#       dtype='object')

# %%
for column in merged_df.columns[1:8]:
    print(f"{column} and Neg posts sum: {pearsonr(sentiment_neg, merged_df[column].values)}")
# Out:
# Confirmed and Neg posts sum: PearsonRResult(statistic=-0.551265419634216, pvalue=9.145738889328163e-10)
# Deaths and Neg posts sum: PearsonRResult(statistic=-0.5492908495093117, pvalue=1.0791467001997835e-09)
# Recovered and Neg posts sum: PearsonRResult(statistic=-0.4504100662197299, pvalue=1.2690020789274206e-06)
# In_the_hospital and Neg posts sum: PearsonRResult(statistic=-0.5258992232065396, pvalue=7.0788110257322565e-09)
# In_quarantine and Neg posts sum: PearsonRResult(statistic=-0.42613218612791287, pvalue=5.254246833784747e-06)
# Under_medical_supervision and Neg posts sum: PearsonRResult(statistic=0.22108496717313528, pvalue=0.022757572579148358)
# Number_of_tests_carried_out and Neg posts sum: PearsonRResult(statistic=-0.48518093740732193, pvalue=1.3570981110953287e-07)

# %%
for column in merged_df.columns[1:8]:
    print(f"{column} and Neg posts sum: {pearsonr(neg_perc, merged_df[column].values)}")
# Out:
# Confirmed and Neg posts sum: PearsonRResult(statistic=-0.19307407260864157, pvalue=0.047373068085750786)
# Deaths and Neg posts sum: PearsonRResult(statistic=-0.19115663746817163, pvalue=0.04965973459538935)
# Recovered and Neg posts sum: PearsonRResult(statistic=-0.16896813920908066, pvalue=0.08336625715231401)
# In_the_hospital and Neg posts sum: PearsonRResult(statistic=-0.1208820672479026, pvalue=0.21707904705317785)
# In_quarantine and Neg posts sum: PearsonRResult(statistic=-0.11717574953171114, pvalue=0.2316107931479606)
# Under_medical_supervision and Neg posts sum: PearsonRResult(statistic=0.07153405138968554, pvalue=0.4661913703856736)
# Number_of_tests_carried_out and Neg posts sum: PearsonRResult(statistic=-0.1792667093225706, pvalue=0.06595860149411104)

# %%
def smooth_column(column, window_size):
    smoothed_column = column.rolling(window=window_size, min_periods=1).mean()
    return smoothed_column

# Пример использования функции
window_size = 30

for column in merged_df.columns:
    if(column not in ['time', 'Timestamp']):
        smoothed_values = smooth_column(merged_df[column], window_size)
        merged_df[column] = smoothed_values

# %%
In_quarantine = merged_df.In_quarantine.values
In_the_hospital = merged_df.In_the_hospital.values
Confirmed = merged_df.Confirmed.values
Deaths = merged_df.Deaths.values
Number_of_tests_carried_out = merged_df.Number_of_tests_carried_out.values
#Deaths_value = merged_df.Deaths_value.values
Recovered = merged_df.Recovered.values
Under_medical_supervision = merged_df.Under_medical_supervision.values
time =  merged_df.time.values
sentiment_mean = merged_df.preds.values
sentiment_neg = merged_df.neg.values
neg_perc = merged_df.neg_perc.values

# %%
fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, sentiment_neg)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
#plt.yscale('log')
plt.ylabel('Neg count')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, neg_perc)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
#plt.yscale('log')
plt.ylabel('Neg percent')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, Confirmed)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('Confirmed')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, In_the_hospital)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('In_the_hospital')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, Number_of_tests_carried_out)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('Number_of_tests_carried_out')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, Deaths)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('Deaths')

fig, ax = plt.subplots(figsize = (15,10))
plt.bar(time, In_quarantine)
#plt.xticks(rotation=90)
max_xticks = 6
#x_step = len(sentiment_neg) // max_xticks
#plt.xticks(range(0, len(sentiment_neg), x_step))
plt.xlabel('date')
plt.ylabel('In_quarantine')
# Out:
# Text(0, 0.5, 'In_quarantine')

# %%
for column in merged_df.columns[1:8]:
    print(f"{column} and Neg posts sum: {pearsonr(sentiment_neg, merged_df[column].values)}")
# Out:
# Confirmed and Neg posts sum: PearsonRResult(statistic=-0.783426123338512, pvalue=3.25552871839033e-23)
# Deaths and Neg posts sum: PearsonRResult(statistic=-0.7786164185301592, pvalue=8.918139213668299e-23)
# Recovered and Neg posts sum: PearsonRResult(statistic=-0.6720175724758677, pvalue=3.1110673577454682e-15)
# In_the_hospital and Neg posts sum: PearsonRResult(statistic=-0.6963490502274802, pvalue=1.157643879475557e-16)
# In_quarantine and Neg posts sum: PearsonRResult(statistic=-0.5376792571379321, pvalue=2.794943727152666e-09)
# Under_medical_supervision and Neg posts sum: PearsonRResult(statistic=0.34927517222408394, pvalue=0.0002428864045226718)
# Number_of_tests_carried_out and Neg posts sum: PearsonRResult(statistic=-0.7205669434271417, pvalue=3.1071027367266707e-18)

# %%
for column in merged_df.columns[1:8]:
    print(f"{column} and Neg posts sum: {pearsonr(neg_perc, merged_df[column].values)}")
# Out:
# Confirmed and Neg posts sum: PearsonRResult(statistic=-0.6397810442635431, pvalue=1.5521968612834455e-13)
# Deaths and Neg posts sum: PearsonRResult(statistic=-0.6517817443108903, pvalue=3.825707829448475e-14)
# Recovered and Neg posts sum: PearsonRResult(statistic=-0.527010069889789, pvalue=6.4946880746105806e-09)
# In_the_hospital and Neg posts sum: PearsonRResult(statistic=-0.5735077685743944, pvalue=1.313418025129952e-10)
# In_quarantine and Neg posts sum: PearsonRResult(statistic=-0.3801918950344477, pvalue=5.821304640004053e-05)
# Under_medical_supervision and Neg posts sum: PearsonRResult(statistic=0.4324339130776997, pvalue=3.6719066567619455e-06)
# Number_of_tests_carried_out and Neg posts sum: PearsonRResult(statistic=-0.5687388859195823, pvalue=2.0156095415211654e-10)
